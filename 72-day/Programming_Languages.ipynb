# %% [markdown]
# <a href="https://colab.research.google.com/github/K-Musty/100-days_of_code/blob/main/72-day/Programming_Languages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Get the Data
#
# Either use the provided .csv file or (optionally) get fresh (the freshest?) data from running an SQL query on StackExchange:
#
# Follow this link to run the query from [StackExchange](https://data.stackexchange.com/stackoverflow/query/675441/popular-programming-languages-per-over-time-eversql-com) to get your own .csv file
#
# <code>
# select dateadd(month, datediff(month, 0, q.CreationDate), 0) m, TagName, count(*)
# from PostTags pt
# join Posts q on q.Id=pt.PostId
# join Tags t on t.Id=pt.TagId
# where TagName in ('java','c','c++','python','c#','javascript','assembly','php','perl','ruby','visual basic','swift','r','object-c','scratch','go','swift','delphi')
# and q.CreationDate < dateadd(month, datediff(month, 0, getdate()), 0)
# group by dateadd(month, datediff(month, 0, q.CreationDate), 0), TagName
# order by dateadd(month, datediff(month, 0, q.CreationDate), 0)
# </code>

# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# **Challenge**: Read the .csv file and store it in a Pandas dataframe

# %%
data = pd.read_csv('QueryResults.csv')

# %% [markdown]
# **Challenge**: Examine the first 5 rows and the last 5 rows of the of the dataframe

# %%
data.head()
# Out:
#                   Date     TagName  Posts
# 0  2008-07-01 00:00:00          c#      3
# 1  2008-08-01 00:00:00    assembly      8
# 2  2008-08-01 00:00:00  javascript    162
# 3  2008-08-01 00:00:00           c     85
# 4  2008-08-01 00:00:00      python    124

# %% [markdown]
# **Challenge:** Check how many rows and how many columns there are.
# What are the dimensions of the dataframe?

# %%
number_of_rows = data.shape[0]
number_of_columns = data.shape[1]
print(f'Number of rows: {number_of_rows}')
print(f'Number of columns: {number_of_columns}')
# Out:
# Number of rows: 1991
# Number of columns: 3

# %% [markdown]
# **Challenge**: Count the number of entries in each column of the dataframe

# %%
data.count()
# Out:
# Date       1991
# TagName    1991
# Posts      1991
# dtype: int64

# %% [markdown]
# **Challenge**: Calculate the total number of post per language.
# Which Programming language has had the highest total number of posts of all time?

# %%
data.groupby('TagName').sum()
# Out:
#                                                          Date    Posts
# TagName
# assembly    2008-08-01 00:00:002008-09-01 00:00:002008-10-...    34852
# c           2008-08-01 00:00:002008-09-01 00:00:002008-10-...   336042
# c#          2008-07-01 00:00:002008-08-01 00:00:002008-09-...  1423530
# c++         2008-08-01 00:00:002008-09-01 00:00:002008-10-...   684210
# delphi      2008-08-01 00:00:002008-09-01 00:00:002008-10-...    46212
# go          2009-11-01 00:00:002009-12-01 00:00:002010-01-...    47499
# java        2008-08-01 00:00:002008-09-01 00:00:002008-10-...  1696403
# javascript  2008-08-01 00:00:002008-09-01 00:00:002008-10-...  2056510
# perl        2008-08-01 00:00:002008-09-01 00:00:002008-10-...    65286
# php         2008-08-01 00:00:002008-09-01 00:00:002008-10-...  1361988
# python      2008-08-01 00:00:002008-09-01 00:00:002008-10-...  1496210
# r           2008-09-01 00:00:002008-11-01 00:00:002008-12-...   356799
# ...

# %% [markdown]
# Some languages are older (e.g., C) and other languages are newer (e.g., Swift). The dataset starts in September 2008.
#
# **Challenge**: How many months of data exist per language? Which language had the fewest months with an entry?

# %%
print(data.groupby('TagName').count())
# Out:
#             Date  Posts
# TagName
# assembly     144    144
# c            144    144
# c#           145    145
# c++          144    144
# delphi       144    144
# go           129    129
# java         144    144
# javascript   144    144
# perl         144    144
# php          144    144
# python       144    144
# r            142    142
# ruby         144    144
# swift        135    135

# %% [markdown]
# ## Data Cleaning
#
# Let's fix the date format to make it more readable. We need to use Pandas to change format from a string of "2008-07-01 00:00:00" to a datetime object with the format of "2008-07-01"

# %%
data['Date'][1]
# Out:
# '2008-08-01 00:00:00'

# %%
type(data['Date'][1])
# Out:
# str

# %%
print(pd.to_datetime(data['Date'][1]))
type(pd.to_datetime(data['Date'][1]))
# Out:
# 2008-08-01 00:00:00
# pandas._libs.tslibs.timestamps.Timestamp

# %%
data.m = pd.to_datetime(data.Date)
data.head()
# Out:
# /tmp/ipython-input-2933485574.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.m = pd.to_datetime(data.Date)
#                   Date     TagName  Posts
# 0  2008-07-01 00:00:00          c#      3
# 1  2008-08-01 00:00:00    assembly      8
# 2  2008-08-01 00:00:00  javascript    162
# 3  2008-08-01 00:00:00           c     85
# 4  2008-08-01 00:00:00      python    124

# %% [markdown]
# # Tests

# %%
test_df = pd.DataFrame({'Age': ['Young', 'Young', 'Young', 'Young', 'Old', 'Old', 'Old', 'Old'],
                        'Actor': ['Jack', 'Arnold', 'Keanu', 'Sylvester', 'Jack', 'Arnold', 'Keanu', 'Sylvester'],
                        'Power': [100, 80, 25, 50, 99, 75, 5, 30]})
test_df
# Out:
#      Age      Actor  Power
# 0  Young       Jack    100
# 1  Young     Arnold     80
# 2  Young      Keanu     25
# 3  Young  Sylvester     50
# 4    Old       Jack     99
# 5    Old     Arnold     75
# 6    Old      Keanu      5
# 7    Old  Sylvester     30

# %%
pivoted_df = test_df.pivot(index='Age', columns='Actor', values='Power')
pivoted_df
# Out:
# Actor  Arnold  Jack  Keanu  Sylvester
# Age
# Old        75    99      5         30
# Young      80   100     25         50

# %% [markdown]
# ## Data Manipulation

# %%
reshaped_data = data.pivot(index='Date', columns='TagName', values='Posts')
reshaped_data
# Out:
# TagName              assembly       c       c#     c++  delphi     go  \
# Date
# 2008-07-01 00:00:00       NaN     NaN      3.0     NaN     NaN    NaN
# 2008-08-01 00:00:00       8.0    85.0    511.0   164.0    14.0    NaN
# 2008-09-01 00:00:00      28.0   321.0   1649.0   755.0   105.0    NaN
# 2008-10-01 00:00:00      15.0   303.0   1989.0   811.0   112.0    NaN
# 2008-11-01 00:00:00      17.0   259.0   1730.0   735.0   141.0    NaN
# ...                       ...     ...      ...     ...     ...    ...
# 2020-03-01 00:00:00     317.0  2670.0   8954.0  5107.0   181.0  719.0
# 2020-04-01 00:00:00     406.0  3472.0  10042.0  6820.0   250.0  887.0
# 2020-05-01 00:00:00     386.0  3602.0   9923.0  7063.0   221.0  826.0
# 2020-06-01 00:00:00     363.0  2757.0   9064.0  6161.0   214.0  765.0
# 2020-07-01 00:00:00     298.0  2294.0   9145.0  5756.0   212.0  743.0
#
# TagName                 java  javascript   perl     php   python       r  \
# Date
# ...

# %% [markdown]
# **Challenge**: What are the dimensions of our new dataframe? How many rows and columns does it have? Print out the column names and print out the first 5 rows of the dataframe.

# %% [markdown]
# **Challenge**: Count the number of entries per programming language. Why might the number of entries be different?

# %% [markdown]
# ## Data Visualisaton with with Matplotlib

# %% [markdown]
# **Challenge**: Use the [matplotlib documentation](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot) to plot a single programming language (e.g., java) on a chart.

# %%
plt.plot(reshaped_data.index, reshaped_data['java'])
plt.show()

# %%
plt.figure(figsize=(16,10))
plt.plot(reshaped_data.index, reshaped_data.java)
plt.show()

# %%
plt.figure(figsize=(16,20))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of posts', fontsize=14)
plt.ylim(0, 35000)
plt.plot(reshaped_data.index, reshaped_data.java)
plt.show()

# %% [markdown]
# **Challenge**: Show two line (e.g. for Java and Python) on the same chart.

# %%
plt.figure(figsize=(16,20))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of posts', fontsize=14)
plt.ylim(0, 35000)
plt.plot(reshaped_data.index, reshaped_data['java'])
plt.plot(reshaped_data.index, reshaped_data['python'])
plt.show()

# %% [markdown]
# # Smoothing out Time Series Data
#
# Time series data can be quite noisy, with a lot of up and down spikes. To better see a trend we can plot an average of, say 6 or 12 observations. This is called the rolling mean. We calculate the average in a window of time and move it forward by one overservation. Pandas has two handy methods already built in to work this out: [rolling()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html) and [mean()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.core.window.rolling.Rolling.mean.html).

# %%
plt.figure(figsize=(16,20))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of posts', fontsize=14)
plt.ylim(0, 35000)

for column in reshaped_data.columns:
    label = reshaped_data[column].name  # Ensure this returns a proper name
    plt.plot(reshaped_data.index, reshaped_data[column], linewidth=3, label=label)

plt.legend()  # Add legend to ensure the labels are shown
plt.show()

# %%
roll_data = reshaped_data.rolling(window=3).mean()
plt.figure(figsize=(16,20))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of posts', fontsize=14)
plt.ylim(0, 35000)

for column in roll_data.columns:
    label = roll_data[column].name  # Ensure this returns a proper name
    plt.plot(roll_data.index, roll_data[column], linewidth=3, label=label)

plt.legend()  # Add legend to ensure the labels are shown
plt.show()

# %%
# for column in reshaped_data.columns:
#     label = reshaped_data[column].name  # Ensure this returns a proper name
#     print(label)
# Out:
# assembly
# c
# c#
# c++
# delphi
# go
# java
# javascript
# perl
# php
# python
# r
# ruby
# swift
